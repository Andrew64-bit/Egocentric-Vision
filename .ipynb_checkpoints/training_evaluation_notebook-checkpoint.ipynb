# %%
import subprocess
import os

# %%
from transformers import ViTConfig, ViTModel

# %% [markdown]
# # Training MLP

# %% [markdown]
# ### Training

# %%
command = [
    'python', 'train_final_classifier.py',
    'model=MLP',
    'name=final_classifier',
    'logname=I3D_10_dense_D1',
    'action=train',
]

# Esegui il comando
result = subprocess.run(command, capture_output=True, text=True)

# Stampa l'output e l'errore
print('Output:', result.stdout)
print('Error:', result.stderr)

# Verifica il codice di uscita
if result.returncode != 0:
    print(f'Command failed with return code {result.returncode}')

# %% [markdown]
# ### Evaluation

# %%
command = [
    'python', 'eval_final_classifier.py',
    'model=MLP',
    'name=final_evaluation',
    'logname=I3D_10_dense_D1',
    'action=test',
]

# Esegui il comando
result = subprocess.run(command, capture_output=True, text=True)

# Stampa l'output e l'errore
print('Output:', result.stdout)
print('Error:', result.stderr)

# Verifica il codice di uscita
if result.returncode != 0:
    print(f'Command failed with return code {result.returncode}')

# %% [markdown]
# # Training MLP with Dropout

# %%
command = [
    'python', 'train_final_classifier.py',
    'model=MLPWithDropout',
    'name=final_classifier',
    'logname=I3D_10_dense_D1',
    'action=train',
]

# Esegui il comando
result = subprocess.run(command, capture_output=True, text=True)

# Stampa l'output e l'errore
print('Output:', result.stdout)
print('Error:', result.stderr)

# Verifica il codice di uscita
if result.returncode != 0:
    print(f'Command failed with return code {result.returncode}')

# %%
command = [
    'python', 'eval_final_classifier.py',
    'model=MLPWithDropout',
    'name=final_evaluation',
    'logname=I3D_10_dense_D1',
    'action=test',
]

# Esegui il comando
result = subprocess.run(command, capture_output=True, text=True)

# Stampa l'output e l'errore
print('Output:', result.stdout)
print('Error:', result.stderr)

# Verifica il codice di uscita
if result.returncode != 0:
    print(f'Command failed with return code {result.returncode}')

# %% [markdown]
# # Transformer

# %%
# !pip install transformers

# %%
command = [
    'python', 'train_final_classifier.py',
    'model=TransformerClassifier',
    'name=final_classifier',
    'logname=I3D_10_dense_D1',
    'action=train',
]

# Esegui il comando
result = subprocess.run(command, capture_output=True, text=True)

# Stampa l'output e l'errore
print('Output:', result.stdout)
print('Error:', result.stderr)

# Verifica il codice di uscita
if result.returncode != 0:
    print(f'Command failed with return code {result.returncode}')
# Out:
# /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: dlopen(/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c1017RegisterOperatorsD1Ev
#   Referenced from: <0EB69795-4559-3C98-9EA1-35B6A988BB99> /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/image.so
#   Expected in:     <E4E2FFCA-031E-3974-A7B0-45408D7F4956> /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torch/lib/libtorch_cpu.dylib
#   warn(f"Failed to load image Python extension: {e}")
# 2024-05-31 17:57:27 LOG ERROR Uncaught exception
# Traceback (most recent call last):
#   File "train_final_classifier.py", line 12, in <module>
#     from transformers import ViTConfig, ViTModel
# ModuleNotFoundError: No module named 'transformers'
# ---------------------------------------------------------------------------
# CalledProcessError                        Traceback (most recent call last)
# Cell In[3], line 1
# ----> 1 get_ipython().run_cell_magic('bash', '', '\nsource ~/miniforge3/bin/activate\nconda activate ./env\n\npython train_final_classifier.py \\\n    model=Transformer \\\n    name=final_classifier \\\n    logname=I3D_10_dense_D1 \\\n    action=train\n')
#
# File ~/GithubProjects/Multimodal-Egocentric-Action-Recognition/env/lib/python3.8/site-packages/IPython/core/interactiveshell.py:2478, in InteractiveShell.run_cell_magic(self, magic_name, line, cell)
#    2476 with self.builtin_trap:
#    2477     args = (magic_arg_s, cell)
# -> 2478     result = fn(*args, **kwargs)
#    2480 # The code below prevents the output from being displayed
#    2481 # when using magics with decodator @output_can_be_silenced
#    2482 # when the last Python token in the expression is a ';'.
#    2483 if getattr(fn, magic.MAGIC_OUTPUT_CAN_BE_SILENCED, False):
#
# File ~/GithubProjects/Multimodal-Egocentric-Action-Recognition/env/lib/python3.8/site-packages/IPython/core/magics/script.py:153, in ScriptMagics._make_script_magic.<locals>.named_script_magic(line, cell)
#     151 else:
#     152     line = script
# --> 153 return self.shebang(line, cell)
#
# File ~/GithubProjects/Multimodal-Egocentric-Action-Recognition/env/lib/python3.8/site-packages/IPython/core/magics/script.py:305, in ScriptMagics.shebang(self, line, cell)
#     300 if args.raise_error and p.returncode != 0:
#     301     # If we get here and p.returncode is still None, we must have
#     302     # killed it but not yet seen its return code. We don't wait for it,
#     303     # in case it's stuck in uninterruptible sleep. -9 = SIGKILL
#     304     rc = p.returncode or -9
# --> 305     raise CalledProcessError(rc, cell)
#
# CalledProcessError: Command 'b'\nsource ~/miniforge3/bin/activate\nconda activate ./env\n\npython train_final_classifier.py \\\n    model=Transformer \\\n    name=final_classifier \\\n    logname=I3D_10_dense_D1 \\\n    action=train\n'' returned non-zero exit status 1.

# %%
command = [
    'python', 'eval_final_classifier.py',
    'model=Transformer',
    'name=final_evaluation',
    'logname=I3D_10_dense_D1',
    'action=test',
]

# Esegui il comando
result = subprocess.run(command, capture_output=True, text=True)

# Stampa l'output e l'errore
print('Output:', result.stdout)
print('Error:', result.stderr)

# Verifica il codice di uscita
if result.returncode != 0:
    print(f'Command failed with return code {result.returncode}')
# Out:
# Output:
# Error: /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: dlopen(/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c1017RegisterOperatorsD1Ev
#   Referenced from: <0EB69795-4559-3C98-9EA1-35B6A988BB99> /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/image.so
#   Expected in:     <E4E2FFCA-031E-3974-A7B0-45408D7F4956> /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torch/lib/libtorch_cpu.dylib
#   warn(f"Failed to load image Python extension: {e}")
# 2024-05-31 12:39:25 LOG INFO Model: Transformer(
#   (positional_encoding): PositionalEncoding()
#   (encoder_layers): ModuleList(
#     (0-5): 6 x EncoderLayer(
#       (self_attn): MultiHeadAttention(
#         (W_q): Linear(in_features=1024, out_features=1024, bias=True)
#         (W_k): Linear(in_features=1024, out_features=1024, bias=True)
#         (W_v): Linear(in_features=1024, out_features=1024, bias=True)
#         (W_o): Linear(in_features=1024, out_features=1024, bias=True)
#       )
#       (feed_forward): PositionWiseFeedForward(
#         (fc1): Linear(in_features=1024, out_features=256, bias=True)
#         (fc2): Linear(in_features=256, out_features=1024, bias=True)
#         (relu): ReLU()
#       )
#       (norm1): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (norm2): LayerNorm((1024,), eps=1e-05, elementwise_affine=True)
#       (dropout): Dropout(p=0.1, inplace=False)
#     )
#   )
#   (fc): Linear(in_features=1024, out_features=8, bias=True)
#   (dropout): Dropout(p=0.1, inplace=False)
# )
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "eval_final_classifier.py", line 79, in <module>
#     test_dataset = FeaturesDataset("./saved_features/saved_feat_I3D_10_dense_D1_test.pkl", 'test')
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/utils/loaders.py", line 325, in __init__
#     logger.info("Training set size:", self.DTR.shape, self.LTR.shape)
# Message: 'Training set size:'
# Arguments: ((1450, 1024), (1450,))
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "eval_final_classifier.py", line 79, in <module>
#     test_dataset = FeaturesDataset("./saved_features/saved_feat_I3D_10_dense_D1_test.pkl", 'test')
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/utils/loaders.py", line 325, in __init__
#     logger.info("Training set size:", self.DTR.shape, self.LTR.shape)
# Message: 'Training set size:'
# Arguments: ((1450, 1024), (1450,))
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "eval_final_classifier.py", line 79, in <module>
#     test_dataset = FeaturesDataset("./saved_features/saved_feat_I3D_10_dense_D1_test.pkl", 'test')
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/utils/loaders.py", line 326, in __init__
#     logger.info("Test set size:", self.DTE.shape, self.LTE.shape)
# Message: 'Test set size:'
# Arguments: ((725, 1024), (725,))
# --- Logging error ---
# Traceback (most recent call last):
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 1085, in emit
#     msg = self.format(record)
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 929, in format
#     return fmt.format(record)
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 668, in format
#     record.message = record.getMessage()
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/logging/__init__.py", line 373, in getMessage
#     msg = msg % self.args
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "eval_final_classifier.py", line 79, in <module>
#     test_dataset = FeaturesDataset("./saved_features/saved_feat_I3D_10_dense_D1_test.pkl", 'test')
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/utils/loaders.py", line 326, in __init__
#     logger.info("Test set size:", self.DTE.shape, self.LTE.shape)
# Message: 'Test set size:'
# Arguments: ((725, 1024), (725,))
# 2024-05-31 12:39:25 LOG INFO Test Dataset Size: 725
#
#   0%|          | 0/725 [00:00<?, ?it/s]2024-05-31 12:39:30 LOG INFO Outputs: torch.Size([32, 8])
# 2024-05-31 12:39:30 LOG INFO Y: torch.Size([1])
# /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: dlopen(/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c1017RegisterOperatorsD1Ev
#   Referenced from: <0EB69795-4559-3C98-9EA1-35B6A988BB99> /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/image.so
#   Expected in:     <E4E2FFCA-031E-3974-A7B0-45408D7F4956> /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torch/lib/libtorch_cpu.dylib
#   warn(f"Failed to load image Python extension: {e}")
# /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: dlopen(/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c1017RegisterOperatorsD1Ev
#   Referenced from: <0EB69795-4559-3C98-9EA1-35B6A988BB99> /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/image.so
#   Expected in:     <E4E2FFCA-031E-3974-A7B0-45408D7F4956> /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torch/lib/libtorch_cpu.dylib
#   warn(f"Failed to load image Python extension: {e}")
# /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: dlopen(/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c1017RegisterOperatorsD1Ev
#   Referenced from: <0EB69795-4559-3C98-9EA1-35B6A988BB99> /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/image.so
#   Expected in:     <E4E2FFCA-031E-3974-A7B0-45408D7F4956> /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torch/lib/libtorch_cpu.dylib
#   warn(f"Failed to load image Python extension: {e}")
# /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/io/image.py:13: UserWarning: Failed to load image Python extension: dlopen(/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/image.so, 0x0006): Symbol not found: __ZN3c1017RegisterOperatorsD1Ev
#   Referenced from: <0EB69795-4559-3C98-9EA1-35B6A988BB99> /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torchvision/image.so
#   Expected in:     <E4E2FFCA-031E-3974-A7B0-45408D7F4956> /Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torch/lib/libtorch_cpu.dylib
#   warn(f"Failed to load image Python extension: {e}")
#
#   0%|          | 0/725 [00:10<?, ?it/s]
# 2024-05-31 12:39:35 LOG ERROR Uncaught exception
# Traceback (most recent call last):
#   File "eval_final_classifier.py", line 88, in <module>
#     test_loss, test_accuracy = evaluate(model, test_loader, DEVICE)
#   File "eval_final_classifier.py", line 27, in evaluate
#     loss = F.cross_entropy(outputs, y.long())
#   File "/Users/andreavannozzi/GithubProjects/Egocentric-Vision/env/lib/python3.8/site-packages/torch/nn/functional.py", line 3086, in cross_entropy
#     return torch._C._nn.cross_entropy_loss(input, target, weight, _Reduction.get_enum(reduction), ignore_index, label_smoothing)
# ValueError: Expected input batch_size (32) to match target batch_size (1).
#
# Command failed with return code 1

# %% [markdown]
# ## LSTM

# %%
command = [
    'python', 'train_final_classifier.py',
    'model=LSTMClassifier',
    'name=final_classifier',
    'logname=I3D_10_dense_D1',
    'action=train',
]

# Esegui il comando
result = subprocess.run(command, capture_output=True, text=True)

# Stampa l'output e l'errore
print('Output:', result.stdout)
print('Error:', result.stderr)

# Verifica il codice di uscita
if result.returncode != 0:
    print(f'Command failed with return code {result.returncode}')
# Out:
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# Cell In[6], line 10
#       1 command = [
#       2     'python', 'train_final_classifier.py',
#       3     'model=LSTMClassifier',
#    (...)
#       6     'action=train',
#       7 ]
#       9 # Esegui il comando
# ---> 10 result = subprocess.run(command, capture_output=True, text=True)
#      12 # Stampa l'output e l'errore
#      13 print('Output:', result.stdout)
#
# File ~/GithubProjects/Multimodal-Egocentric-Action-Recognition/env/lib/python3.8/subprocess.py:495, in run(input, capture_output, timeout, check, *popenargs, **kwargs)
#     493 with Popen(*popenargs, **kwargs) as process:
#     494     try:
# --> 495         stdout, stderr = process.communicate(input, timeout=timeout)
#     496     except TimeoutExpired as exc:
#     497         process.kill()
#
# File ~/GithubProjects/Multimodal-Egocentric-Action-Recognition/env/lib/python3.8/subprocess.py:1028, in Popen.communicate(self, input, timeout)
#    1025     endtime = None
#    1027 try:
# -> 1028     stdout, stderr = self._communicate(input, endtime, timeout)
#    1029 except KeyboardInterrupt:
#    1030     # https://bugs.python.org/issue25942
#    1031     # See the detailed comment in .wait().
#    1032     if timeout is not None:
#
# File ~/GithubProjects/Multimodal-Egocentric-Action-Recognition/env/lib/python3.8/subprocess.py:1884, in Popen._communicate(self, input, endtime, orig_timeout)
#    1877     self._check_timeout(endtime, orig_timeout,
#    1878                         stdout, stderr,
#    1879                         skip_check_and_raise=True)
#    1880     raise RuntimeError(  # Impossible :)
#    1881         '_check_timeout(..., skip_check_and_raise=True) '
#    1882         'failed to raise TimeoutExpired.')
# -> 1884 ready = selector.select(timeout)
#    1885 self._check_timeout(endtime, orig_timeout, stdout, stderr)
#    1887 # XXX Rewrite these to use non-blocking I/O on the file
#    1888 # objects; they are no longer using C stdio!
#
# File ~/GithubProjects/Multimodal-Egocentric-Action-Recognition/env/lib/python3.8/selectors.py:415, in _PollLikeSelector.select(self, timeout)
#     413 ready = []
#     414 try:
# --> 415     fd_event_list = self._selector.poll(timeout)
#     416 except InterruptedError:
#     417     return ready
#
# KeyboardInterrupt:

# %%
command = [
    'python', 'eval_final_classifier.py',
    'model=LSTMClassifier',
    'name=final_evaluation',
    'logname=I3D_10_dense_D1',
    'action=test',
]

# Esegui il comando
result = subprocess.run(command, capture_output=True, text=True)

# Stampa l'output e l'errore
print('Output:', result.stdout)
print('Error:', result.stderr)

# Verifica il codice di uscita
if result.returncode != 0:
    print(f'Command failed with return code {result.returncode}')
# Out:
# Output:
# Error: 2024-05-30 21:50:29 LOG INFO Model: LSTMClassifier(
#   (lstm): LSTM(1024, 128, num_layers=2, batch_first=True)
#   (fc): Linear(in_features=128, out_features=8, bias=True)
# )
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Users\iplov\Desktop\Advanced ML\Progetto\github andrew\Egocentric-Vision\eval_final_classifier.py", line 71, in <module>
#     test_dataset = FeaturesDataset("./saved_features/saved_feat_I3D_10_dense_D1_test.pkl", 'test')
#   File "c:\Users\iplov\Desktop\Advanced ML\Progetto\github andrew\Egocentric-Vision\utils\loaders.py", line 325, in __init__
#     logger.info("Training set size:", self.DTR.shape, self.LTR.shape)
# Message: 'Training set size:'
# Arguments: ((1450, 1024), (1450,))
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\site-packages\coloredlogs\__init__.py", line 1140, in format
#     return logging.Formatter.format(self, record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Users\iplov\Desktop\Advanced ML\Progetto\github andrew\Egocentric-Vision\eval_final_classifier.py", line 71, in <module>
#     test_dataset = FeaturesDataset("./saved_features/saved_feat_I3D_10_dense_D1_test.pkl", 'test')
#   File "c:\Users\iplov\Desktop\Advanced ML\Progetto\github andrew\Egocentric-Vision\utils\loaders.py", line 325, in __init__
#     logger.info("Training set size:", self.DTR.shape, self.LTR.shape)
# Message: 'Training set size:'
# Arguments: ((1450, 1024), (1450,))
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Users\iplov\Desktop\Advanced ML\Progetto\github andrew\Egocentric-Vision\eval_final_classifier.py", line 71, in <module>
#     test_dataset = FeaturesDataset("./saved_features/saved_feat_I3D_10_dense_D1_test.pkl", 'test')
#   File "c:\Users\iplov\Desktop\Advanced ML\Progetto\github andrew\Egocentric-Vision\utils\loaders.py", line 326, in __init__
#     logger.info("Test set size:", self.DTE.shape, self.LTE.shape)
# Message: 'Test set size:'
# Arguments: ((725, 1024), (725,))
# --- Logging error ---
# Traceback (most recent call last):
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 1110, in emit
#     msg = self.format(record)
#           ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 953, in format
#     return fmt.format(record)
#            ^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\site-packages\coloredlogs\__init__.py", line 1140, in format
#     return logging.Formatter.format(self, record)
#            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 687, in format
#     record.message = record.getMessage()
#                      ^^^^^^^^^^^^^^^^^^^
#   File "c:\Users\iplov\miniconda3\envs\aml_ego\Lib\logging\__init__.py", line 377, in getMessage
#     msg = msg % self.args
#           ~~~~^~~~~~~~~~~
# TypeError: not all arguments converted during string formatting
# Call stack:
#   File "c:\Users\iplov\Desktop\Advanced ML\Progetto\github andrew\Egocentric-Vision\eval_final_classifier.py", line 71, in <module>
#     test_dataset = FeaturesDataset("./saved_features/saved_feat_I3D_10_dense_D1_test.pkl", 'test')
#   File "c:\Users\iplov\Desktop\Advanced ML\Progetto\github andrew\Egocentric-Vision\utils\loaders.py", line 326, in __init__
#     logger.info("Test set size:", self.DTE.shape, self.LTE.shape)
# Message: 'Test set size:'
# Arguments: ((725, 1024), (725,))
# 2024-05-30 21:50:29 LOG INFO Test Dataset Size: 725
#
#   0%|          | 0/725 [00:00<?, ?it/s]
#   0%|          | 1/725 [01:00<12:06:26, 60.20s/it]
#   5%|▍         | 36/725 [01:00<13:35,  1.18s/it]
#  10%|▉         | 71/725 [01:00<05:23,  2.02it/s]
#  14%|█▍        | 104/725 [01:00<02:52,  3.59it/s]
#  19%|█▉        | 139/725 [01:00<01:38,  5.94it/s]
#  24%|██▎       | 171/725 [01:00<01:02,  8.81it/s]
#  27%|██▋       | 196/725 [01:01<00:44, 11.93it/s]
#  30%|███       | 218/725 [01:01<00:32, 15.63it/s]
#  33%|███▎      | 238/725 [01:01<00:24, 20.21it/s]
#  37%|███▋      | 267/725 [01:01<00:15, 29.56it/s]
#  40%|████      | 293/725 [01:01<00:10, 40.50it/s]
#  44%|████▎     | 316/725 [01:01<00:07, 52.48it/s]
#  47%|████▋     | 343/725 [01:01<00:05, 70.54it/s]
#  51%|█████     | 370/725 [01:01<00:03, 91.71it/s]
#  54%|█████▍    | 395/725 [01:01<00:03, 109.68it/s]
#  58%|█████▊    | 419/725 [01:02<00:02, 129.53it/s]
#  62%|██████▏   | 446/725 [01:02<00:01, 154.56it/s]
#  66%|██████▌   | 476/725 [01:02<00:01, 183.14it/s]
#  70%|███████   | 510/725 [01:02<00:00, 216.35it/s]
#  75%|███████▌  | 546/725 [01:02<00:00, 250.72it/s]
#  80%|███████▉  | 579/725 [01:02<00:00, 270.55it/s]
#  84%|████████▍ | 612/725 [01:02<00:00, 285.98it/s]
#  90%|████████▉ | 649/725 [01:02<00:00, 301.21it/s]
#  95%|█████████▍| 686/725 [01:02<00:00, 314.99it/s]
#  99%|█████████▉| 720/725 [01:03<00:00, 313.42it/s]
# 100%|██████████| 725/725 [01:04<00:00, 11.27it/s]
# 2024-05-30 21:51:33 LOG INFO Test Loss: 1.6907286589721153, Test Accuracy: 0.4013793170452118
